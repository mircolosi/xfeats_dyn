# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir('/home/com2rng/kaggle/xfeats_dyn')

# %%
import torch
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
from xfeats_dyn.dataset import Coco2017DataModule

datamodule = Coco2017DataModule()
datamodule.setup('fit')
# Out:
# 2024-12-20 11:48:17.502 | INFO     | xfeats_dyn.config:<module>:11 - PROJ_ROOT path is: /home/com2rng/kaggle/xfeats_dyn
# Setting up stage fit...

# %%
dataloader = datamodule.train_dataloader()
# Out:
# 2024-12-20 11:48:37.114 | INFO     | xfeats_dyn.dataset:train_dataloader:214 - Loading train dataloader...

# %%
# a, b = dataloader.dataset[0]
dataloader.dataset.stage="debug"
for i in range (10):
    dataloader.dataset[i]
# a = dataloader.dataset[32]
# Out:
# 2024-12-20 11:50:58.308 | INFO     | xfeats_dyn.dataset:__getitem__:121 - segmentation_mask[1:, :, :].shape=torch.Size([4, 480, 640])
# 2024-12-20 11:50:58.539 | INFO     | xfeats_dyn.dataset:__getitem__:129 - /home/com2rng/kaggle/xfeats_dyn/data/raw/2017/train2017/000000391895.jpg [idx=0], squashed_mask.shape=torch.Size([1, 480, 640])
# 2024-12-20 11:50:58.612 | INFO     | xfeats_dyn.dataset:__getitem__:121 - segmentation_mask[1:, :, :].shape=torch.Size([4, 480, 640])
# 2024-12-20 11:50:58.845 | INFO     | xfeats_dyn.dataset:__getitem__:129 - /home/com2rng/kaggle/xfeats_dyn/data/raw/2017/train2017/000000522418.jpg [idx=1], squashed_mask.shape=torch.Size([1, 480, 640])
# 2024-12-20 11:50:58.946 | INFO     | xfeats_dyn.dataset:__getitem__:121 - segmentation_mask[1:, :, :].shape=torch.Size([4, 480, 640])
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir tb_logs/
# Out:
#       <iframe id="tensorboard-frame-d492ab35b930f358" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d492ab35b930f358");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
